# %%
import pandas as pd
df = pd.read_csv('../../yelpdata/yelp-csv/yelp_academic_dataset_business.csv')
df
# Out:
#                                          address  \
# 0                    2818 E Camino Acequia Drive
# 1                           30 Eglinton Avenue W
# 2                   1210 8th Street SW, Unit 220
# 3                    6955 N Durango Dr, Ste 1116
# 4                              4 E University Dr
# ...                                          ...
# 192604                521 St. Catherine Street W
# 192605                       244 Victoria Street
# 192606                       10210 South 50th Pl
# 192607  6670 S Tenaya Way, Ste 120, The Body Spa
# 192608                 14050 N 83rd Ave, Ste 290
#
#                                                attributes  \
# 0                                                      {}
# 1       {'GoodForMeal': "{'dessert': False, 'latenight...
# 2       {'BusinessParking': "{'garage': False, 'street...
# 3       {'BusinessParking': "{'garage': False, 'street...
# 4                                                      {}
# ...                                                   ...
# 192604  {'Ambience': "{'romantic': False, 'intimate': ...
# 192605                                                 {}
# 192606                                                NaN
# 192607  {'BusinessParking': "{'garage': False, 'street...
# 192608                                                NaN
#
#                    business_id  \
# 0       1SWheh84yJXfytovILXOAQ
# 1       QXAEGFB4oINsVuTFxEYKFQ
# 2       fcXOEZdXYeZqnQ3lGlOXmg
# 3       f2ZWZPENViL92BrFsIgR6w
# 4       6KgGE8B1RsR7jc9R5nuH0Q
# ...                        ...
# 192604  wWV90q48ugyxyXW6gZav8w
# 192605  phSaT3I_y6To1J2OdeFSUQ
# 192606  oU6Q3ymg1Qsh1EUI6oQwQg
# 192607  gdiOk0n7DmNE9w8xeHWkvw
# 192608  Rv8s4io4G4mcUpiDbpzy7w
#
#                                                categories         city  \
# 0                                       Golf, Active Life      Phoenix
# 1       Specialty Food, Restaurants, Dim Sum, Imported...  Mississauga
# 2       Local Services, Professional Services, Compute...      Calgary
# 3                              Beauty & Spas, Hair Salons    Las Vegas
# 4                     American (Traditional), Restaurants        Tempe
# ...                                                   ...          ...
# 192604            Restaurants, Venezuelan, Latin American     Montréal
# 192605              Arts & Entertainment, Performing Arts      Toronto
# 192606           Education, Middle Schools & High Schools      Phoenix
# 192607  Beauty & Spas, Eyelash Service, Waxing, Esthet...    Las Vegas
# 192608  Professional Services, Wills, Trusts, & Probat...       Peoria
#
#                                                     hours  is_open   latitude  \
# 0                                                     NaN        0  33.522143
# 1       {'Monday': '9:0-0:0', 'Tuesday': '9:0-0:0', 'W...        1  43.605499
# 2       {'Monday': '9:0-17:0', 'Tuesday': '9:0-17:0', ...        1  51.041771
# 3       {'Monday': '8:30-20:0', 'Tuesday': '8:30-20:0'...        1  36.287312
# 4                                                     NaN        0  33.422192
# ...                                                   ...      ...        ...
# 192604                                                NaN        0  45.504597
# 192605                                                NaN        1  43.655290
# 192606  {'Monday': '7:30-17:30', 'Tuesday': '7:30-17:3...        1  33.354284
# 192607  {'Monday': '0:0-0:0', 'Tuesday': '9:0-19:0', '...        1  36.066952
# 192608  {'Monday': '8:0-18:0', 'Tuesday': '8:0-18:0', ...        1  33.612226
#
#          longitude                         name postal_code  review_count  \
# 0      -112.018481   Arizona Biltmore Golf Club       85016             5
# 1       -79.652289   Emerald Chinese Restaurant     L5R 3E7           128
# 2      -114.081109  Nucleus Information Service     T2R 1L3             5
# 3      -115.289540                 Amazing Cuts       89149           116
# 4      -111.939615                 Ruby Tuesday       85281             9
# ...            ...                          ...         ...           ...
# 192604  -73.568456                       Arepas     H3B 1A6            15
# 192605  -79.379541           Ed Mirvish Theatre     M5B 1V8            58
# 192606 -111.975538              BASIS Ahwatukee       85044             3
# 192607 -115.251008              Brows Redefined       89113            15
# 192608 -112.238145   Affordable Estate Planning       85381             3
#
#         stars state
# 0         3.0    AZ
# 1         2.5    ON
# 2         2.0    AB
# 3         4.5    NV
# 4         2.5    AZ
# ...       ...   ...
# 192604    3.5    QC
# 192605    4.0    ON
# 192606    2.5    AZ
# 192607    5.0    NV
# 192608    5.0    AZ
#
# [192609 rows x 14 columns]

# %%
## it was missing address so I put it there 
## technically this shit stadium has a set of address from 12030 to 12040 but in the assumptions we can say we assume only the main entrance of the business should be considered
df.loc[119357, ['city', 'address', 'postal_code']] = ['Mesa', '12033 S Sossaman Rd', '85212']
df.loc[119357]
# Out:
# address                                       12033 S Sossaman Rd
# attributes      {'BusinessParking': "{'garage': False, 'street...
# business_id                                WpC53SqwoCY5AuYIFr_1eA
# categories                                    Soccer, Active Life
# city                                                         Mesa
# hours                                                         NaN
# is_open                                                         1
# latitude                                                  33.3381
# longitude                                                -111.678
# name                                 NSFC Strikers Soccer Complex
# postal_code                                                 85212
# review_count                                                    3
# stars                                                         2.5
# state                                                          AZ
# Name: 119357, dtype: object

# %%
dfhasLocAB = pd.DataFrame(df[['latitude','longitude', 'business_id', 'address', 'city', 'state']])
dfhasLocAB
# Out:
#          latitude   longitude             business_id  \
# 0       33.522143 -112.018481  1SWheh84yJXfytovILXOAQ
# 1       43.605499  -79.652289  QXAEGFB4oINsVuTFxEYKFQ
# 2       51.041771 -114.081109  fcXOEZdXYeZqnQ3lGlOXmg
# 3       36.287312 -115.289540  f2ZWZPENViL92BrFsIgR6w
# 4       33.422192 -111.939615  6KgGE8B1RsR7jc9R5nuH0Q
# ...           ...         ...                     ...
# 192604  45.504597  -73.568456  wWV90q48ugyxyXW6gZav8w
# 192605  43.655290  -79.379541  phSaT3I_y6To1J2OdeFSUQ
# 192606  33.354284 -111.975538  oU6Q3ymg1Qsh1EUI6oQwQg
# 192607  36.066952 -115.251008  gdiOk0n7DmNE9w8xeHWkvw
# 192608  33.612226 -112.238145  Rv8s4io4G4mcUpiDbpzy7w
#
#                                          address         city state
# 0                    2818 E Camino Acequia Drive      Phoenix    AZ
# 1                           30 Eglinton Avenue W  Mississauga    ON
# 2                   1210 8th Street SW, Unit 220      Calgary    AB
# 3                    6955 N Durango Dr, Ste 1116    Las Vegas    NV
# 4                              4 E University Dr        Tempe    AZ
# ...                                          ...          ...   ...
# 192604                521 St. Catherine Street W     Montréal    QC
# 192605                       244 Victoria Street      Toronto    ON
# 192606                       10210 South 50th Pl      Phoenix    AZ
# 192607  6670 S Tenaya Way, Ste 120, The Body Spa    Las Vegas    NV
# 192608                 14050 N 83rd Ave, Ste 290       Peoria    AZ
#
# [192609 rows x 6 columns]

# %%
dfhasLocAB.rename(columns={'address':'streetAddr', 'city':'cityName', 'state':'stateName'}, inplace=True)
dfhasLocAB.to_csv('hasLocationAB.csv', index=False)
dfhasLocAB
# Out:
#          latitude   longitude             business_id  \
# 0       33.522143 -112.018481  1SWheh84yJXfytovILXOAQ
# 1       43.605499  -79.652289  QXAEGFB4oINsVuTFxEYKFQ
# 2       51.041771 -114.081109  fcXOEZdXYeZqnQ3lGlOXmg
# 3       36.287312 -115.289540  f2ZWZPENViL92BrFsIgR6w
# 4       33.422192 -111.939615  6KgGE8B1RsR7jc9R5nuH0Q
# ...           ...         ...                     ...
# 192604  45.504597  -73.568456  wWV90q48ugyxyXW6gZav8w
# 192605  43.655290  -79.379541  phSaT3I_y6To1J2OdeFSUQ
# 192606  33.354284 -111.975538  oU6Q3ymg1Qsh1EUI6oQwQg
# 192607  36.066952 -115.251008  gdiOk0n7DmNE9w8xeHWkvw
# 192608  33.612226 -112.238145  Rv8s4io4G4mcUpiDbpzy7w
#
#                                       streetAddr     cityName stateName
# 0                    2818 E Camino Acequia Drive      Phoenix        AZ
# 1                           30 Eglinton Avenue W  Mississauga        ON
# 2                   1210 8th Street SW, Unit 220      Calgary        AB
# 3                    6955 N Durango Dr, Ste 1116    Las Vegas        NV
# 4                              4 E University Dr        Tempe        AZ
# ...                                          ...          ...       ...
# 192604                521 St. Catherine Street W     Montréal        QC
# 192605                       244 Victoria Street      Toronto        ON
# 192606                       10210 South 50th Pl      Phoenix        AZ
# 192607  6670 S Tenaya Way, Ste 120, The Body Spa    Las Vegas        NV
# 192608                 14050 N 83rd Ave, Ste 290       Peoria        AZ
#
# [192609 rows x 6 columns]

# %%
############################### table hasLocationAB done #################################

# %%
dfaddrAB = pd.DataFrame(df[['postal_code','address', 'city', 'state']])
dfaddrAB
# Out:
#        postal_code                                   address         city  \
# 0            85016               2818 E Camino Acequia Drive      Phoenix
# 1          L5R 3E7                      30 Eglinton Avenue W  Mississauga
# 2          T2R 1L3              1210 8th Street SW, Unit 220      Calgary
# 3            89149               6955 N Durango Dr, Ste 1116    Las Vegas
# 4            85281                         4 E University Dr        Tempe
# ...            ...                                       ...          ...
# 192604     H3B 1A6                521 St. Catherine Street W     Montréal
# 192605     M5B 1V8                       244 Victoria Street      Toronto
# 192606       85044                       10210 South 50th Pl      Phoenix
# 192607       89113  6670 S Tenaya Way, Ste 120, The Body Spa    Las Vegas
# 192608       85381                 14050 N 83rd Ave, Ste 290       Peoria
#
#        state
# 0         AZ
# 1         ON
# 2         AB
# 3         NV
# 4         AZ
# ...      ...
# 192604    QC
# 192605    ON
# 192606    AZ
# 192607    NV
# 192608    AZ
#
# [192609 rows x 4 columns]

# %%
dfaddrAB.rename(columns={'address':'streetAddr', 'city':'cityName', 'state':'stateName', 'postal_code':'postalCode'}, inplace=True)
dfaddrAB
# Out:
#        postalCode                                streetAddr     cityName  \
# 0           85016               2818 E Camino Acequia Drive      Phoenix
# 1         L5R 3E7                      30 Eglinton Avenue W  Mississauga
# 2         T2R 1L3              1210 8th Street SW, Unit 220      Calgary
# 3           89149               6955 N Durango Dr, Ste 1116    Las Vegas
# 4           85281                         4 E University Dr        Tempe
# ...           ...                                       ...          ...
# 192604    H3B 1A6                521 St. Catherine Street W     Montréal
# 192605    M5B 1V8                       244 Victoria Street      Toronto
# 192606      85044                       10210 South 50th Pl      Phoenix
# 192607      89113  6670 S Tenaya Way, Ste 120, The Body Spa    Las Vegas
# 192608      85381                 14050 N 83rd Ave, Ste 290       Peoria
#
#        stateName
# 0             AZ
# 1             ON
# 2             AB
# 3             NV
# 4             AZ
# ...          ...
# 192604        QC
# 192605        ON
# 192606        AZ
# 192607        NV
# 192608        AZ
#
# [192609 rows x 4 columns]

# %%
# remove duplicates
dfaddrAB.drop_duplicates(keep ='first', inplace = True)
dfaddrAB.to_csv('addressAB.csv', index=False)
dfaddrAB
###################################### table addressAB done ###########################################
# Out:
#        postalCode                                streetAddr     cityName  \
# 0           85016               2818 E Camino Acequia Drive      Phoenix
# 1         L5R 3E7                      30 Eglinton Avenue W  Mississauga
# 2         T2R 1L3              1210 8th Street SW, Unit 220      Calgary
# 3           89149               6955 N Durango Dr, Ste 1116    Las Vegas
# 4           85281                         4 E University Dr        Tempe
# ...           ...                                       ...          ...
# 192603      85210                        440 S Extension Rd         Mesa
# 192604    H3B 1A6                521 St. Catherine Street W     Montréal
# 192605    M5B 1V8                       244 Victoria Street      Toronto
# 192606      85044                       10210 South 50th Pl      Phoenix
# 192607      89113  6670 S Tenaya Way, Ste 120, The Body Spa    Las Vegas
#
#        stateName
# 0             AZ
# 1             ON
# 2             AB
# 3             NV
# 4             AZ
# ...          ...
# 192603        AZ
# 192604        QC
# 192605        ON
# 192606        AZ
# 192607        NV
#
# [157603 rows x 4 columns]

# %%
#actually a shit ton of values are nan as you can see so I discard them
import numpy as np
for index, row in dfaddrAB.iterrows():
    if (type(row['streetAddr']) is float):
        print('garbage present with index2 '+ str(index))
        print(str(row))
print('done')
# Out:
# garbage present with index2 27
# postalCode    85204
# streetAddr      NaN
# cityName       Mesa
# stateName        AZ
# Name: 27, dtype: object
# garbage present with index2 28
# postalCode        28273
# streetAddr          NaN
# cityName      Charlotte
# stateName            NC
# Name: 28, dtype: object
# garbage present with index2 35
# postalCode    85284
# streetAddr      NaN
# cityName      Tempe
# stateName        AZ
# Name: 35, dtype: object
# garbage present with index2 43
# postalCode        89102
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 43, dtype: object
# garbage present with index2 47
# postalCode      85040
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 47, dtype: object
# garbage present with index2 69
# postalCode        89012
# streetAddr          NaN
# cityName      Henderson
# stateName            NV
# Name: 69, dtype: object
# garbage present with index2 79
# postalCode     J4Y 1A2
# streetAddr         NaN
# cityName      Montréal
# stateName           QC
# Name: 79, dtype: object
# garbage present with index2 104
# postalCode        88901
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 104, dtype: object
# garbage present with index2 149
# postalCode         85250
# streetAddr           NaN
# cityName      Scottsdale
# stateName             AZ
# Name: 149, dtype: object
# garbage present with index2 159
# postalCode      85299
# streetAddr        NaN
# cityName      Gilbert
# stateName          AZ
# Name: 159, dtype: object
# garbage present with index2 162
# postalCode        28105
# streetAddr          NaN
# cityName      Charlotte
# stateName            NC
# Name: 162, dtype: object
# garbage present with index2 163
# postalCode        89109
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 163, dtype: object
# garbage present with index2 208
# postalCode      85351
# streetAddr        NaN
# cityName      Suncity
# stateName          AZ
# Name: 208, dtype: object
# garbage present with index2 245
# postalCode        T3J
# streetAddr        NaN
# cityName      Calgary
# stateName          AB
# Name: 245, dtype: object
# garbage present with index2 282
# postalCode        61824
# streetAddr          NaN
# cityName      Champaign
# stateName            IL
# Name: 282, dtype: object
# garbage present with index2 313
# postalCode        89117
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 313, dtype: object
# garbage present with index2 324
# postalCode      85003
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 324, dtype: object
# garbage present with index2 420
# postalCode        89144
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 420, dtype: object
# garbage present with index2 429
# postalCode       85286
# streetAddr         NaN
# cityName      Chandler
# stateName           AZ
# Name: 429, dtype: object
# garbage present with index2 476
# postalCode        NaN
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 476, dtype: object
# garbage present with index2 481
# postalCode        28213
# streetAddr          NaN
# cityName      Charlotte
# stateName            NC
# Name: 481, dtype: object
# garbage present with index2 492
# postalCode        NaN
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 492, dtype: object
# garbage present with index2 543
# postalCode      85014
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 543, dtype: object
# garbage present with index2 552
# postalCode      85016
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 552, dtype: object
# garbage present with index2 566
# postalCode       85392
# streetAddr         NaN
# cityName      Avondale
# stateName           AZ
# Name: 566, dtype: object
# garbage present with index2 575
# postalCode        89044
# streetAddr          NaN
# cityName      Henderson
# stateName            NV
# Name: 575, dtype: object
# garbage present with index2 586
# postalCode        89101
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 586, dtype: object
# garbage present with index2 593
# postalCode        89121
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 593, dtype: object
# garbage present with index2 622
# postalCode        89106
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 622, dtype: object
# garbage present with index2 649
# postalCode         85251
# streetAddr           NaN
# cityName      Scottsdale
# stateName             AZ
# Name: 649, dtype: object
# garbage present with index2 718
# postalCode      85070
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 718, dtype: object
# garbage present with index2 740
# postalCode      85020
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 740, dtype: object
# garbage present with index2 756
# postalCode        89130
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 756, dtype: object
# garbage present with index2 779
# postalCode    85201
# streetAddr      NaN
# cityName       Mesa
# stateName        AZ
# Name: 779, dtype: object
# garbage present with index2 781
# postalCode       85249
# streetAddr         NaN
# cityName      Chandler
# stateName           AZ
# Name: 781, dtype: object
# garbage present with index2 848
# postalCode       85388
# streetAddr         NaN
# cityName      Surprise
# stateName           AZ
# Name: 848, dtype: object
# garbage present with index2 932
# postalCode      NaN
# streetAddr      NaN
# cityName      Tempe
# stateName        AZ
# Name: 932, dtype: object
# garbage present with index2 952
# postalCode      85032
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 952, dtype: object
# garbage present with index2 963
# postalCode            85375
# streetAddr              NaN
# cityName      Sun City West
# stateName                AZ
# Name: 963, dtype: object
# garbage present with index2 1100
# postalCode        28031
# streetAddr          NaN
# cityName      Charlotte
# stateName            NC
# Name: 1100, dtype: object
# garbage present with index2 1204
# postalCode        89147
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 1204, dtype: object
# garbage present with index2 1235
# postalCode    85202
# streetAddr      NaN
# cityName       Mesa
# stateName        AZ
# Name: 1235, dtype: object
# garbage present with index2 1304
# postalCode        89011
# streetAddr          NaN
# cityName      Henderson
# stateName            NV
# Name: 1304, dtype: object
# garbage present with index2 1305
# postalCode      85295
# streetAddr        NaN
# cityName      Gilbert
# stateName          AZ
# Name: 1305, dtype: object
# garbage present with index2 1357
# postalCode        89104
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 1357, dtype: object
# garbage present with index2 1393
# postalCode    85214
# streetAddr      NaN
# cityName       Mesa
# stateName        AZ
# Name: 1393, dtype: object
# garbage present with index2 1427
# postalCode       85226
# streetAddr         NaN
# cityName      Chandler
# stateName           AZ
# Name: 1427, dtype: object
# garbage present with index2 1432
# postalCode         85337
# streetAddr           NaN
# cityName      Cave Creek
# stateName             AZ
# Name: 1432, dtype: object
# garbage present with index2 1434
# postalCode      85021
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 1434, dtype: object
# garbage present with index2 1503
# postalCode      53725
# streetAddr        NaN
# cityName      Madison
# stateName          WI
# Name: 1503, dtype: object
# garbage present with index2 1522
# postalCode        89134
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 1522, dtype: object
# garbage present with index2 1610
# postalCode            44070
# streetAddr              NaN
# cityName      North Olmsted
# stateName                OH
# Name: 1610, dtype: object
# garbage present with index2 1633
# postalCode        89142
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 1633, dtype: object
# garbage present with index2 1649
# postalCode      85012
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 1649, dtype: object
# garbage present with index2 1709
# postalCode        NaN
# streetAddr        NaN
# cityName      Calgary
# stateName          AB
# Name: 1709, dtype: object
# garbage present with index2 1739
# postalCode        89131
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 1739, dtype: object
# garbage present with index2 1756
# postalCode       85301
# streetAddr         NaN
# cityName      Glendale
# stateName           AZ
# Name: 1756, dtype: object
# garbage present with index2 1903
# postalCode        89120
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 1903, dtype: object
# garbage present with index2 1946
# postalCode      85018
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 1946, dtype: object
# garbage present with index2 1954
# postalCode         85257
# streetAddr           NaN
# cityName      Scottsdale
# stateName             AZ
# Name: 1954, dtype: object
# garbage present with index2 1989
# postalCode      85045
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 1989, dtype: object
# garbage present with index2 2009
# postalCode     85373
# streetAddr       NaN
# cityName      Peoria
# stateName         AZ
# Name: 2009, dtype: object
# garbage present with index2 2022
# postalCode          NaN
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 2022, dtype: object
# garbage present with index2 2092
# postalCode        89129
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 2092, dtype: object
# garbage present with index2 2200
# postalCode        89118
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 2200, dtype: object
# garbage present with index2 2209
# postalCode    T2G 4E6
# streetAddr        NaN
# cityName      Calgary
# stateName          AB
# Name: 2209, dtype: object
# garbage present with index2 2336
# postalCode        89113
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 2336, dtype: object
# garbage present with index2 2351
# postalCode        28031
# streetAddr          NaN
# cityName      Cornelius
# stateName            NC
# Name: 2351, dtype: object
# garbage present with index2 2411
# postalCode         NaN
# streetAddr         NaN
# cityName      Chandler
# stateName           AZ
# Name: 2411, dtype: object
# garbage present with index2 2453
# postalCode     NaN
# streetAddr     NaN
# cityName      Mesa
# stateName       AZ
# Name: 2453, dtype: object
# garbage present with index2 2462
# postalCode      85283
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 2462, dtype: object
# garbage present with index2 2560
# postalCode      85005
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 2560, dtype: object
# garbage present with index2 2622
# postalCode          15290
# streetAddr            NaN
# cityName      Pittsburgh
# stateName              PA
# Name: 2622, dtype: object
# garbage present with index2 2687
# postalCode              89031
# streetAddr                NaN
# cityName      North Las Vegas
# stateName                  NV
# Name: 2687, dtype: object
# garbage present with index2 2750
# postalCode    L3R 4S8
# streetAddr        NaN
# cityName      Markham
# stateName          ON
# Name: 2750, dtype: object
# garbage present with index2 2822
# postalCode       85395
# streetAddr         NaN
# cityName      Goodyear
# stateName           AZ
# Name: 2822, dtype: object
# garbage present with index2 2845
# postalCode    85205
# streetAddr      NaN
# cityName       Mesa
# stateName        AZ
# Name: 2845, dtype: object
# garbage present with index2 2964
# postalCode        89103
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 2964, dtype: object
# garbage present with index2 2983
# postalCode      85069
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 2983, dtype: object
# garbage present with index2 2997
# postalCode         85331
# streetAddr           NaN
# cityName      Cave Creek
# stateName             AZ
# Name: 2997, dtype: object
# garbage present with index2 3025
# postalCode      85009
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 3025, dtype: object
# garbage present with index2 3030
# postalCode      85050
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 3030, dtype: object
# garbage present with index2 3051
# postalCode       85308
# streetAddr         NaN
# cityName      Glendale
# stateName           AZ
# Name: 3051, dtype: object
# garbage present with index2 3078
# postalCode        28262
# streetAddr          NaN
# cityName      Charlotte
# stateName            NC
# Name: 3078, dtype: object
# garbage present with index2 3171
# postalCode             44223
# streetAddr               NaN
# cityName      Cuyahoga Falls
# stateName                 OH
# Name: 3171, dtype: object
# garbage present with index2 3195
# postalCode      85048
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 3195, dtype: object
# garbage present with index2 3262
# postalCode        89149
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 3262, dtype: object
# garbage present with index2 3282
# postalCode        89148
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 3282, dtype: object
# garbage present with index2 3299
# postalCode        28205
# streetAddr          NaN
# cityName      Charlotte
# stateName            NC
# Name: 3299, dtype: object
# garbage present with index2 3331
# postalCode    85246
# streetAddr      NaN
# cityName       Mesa
# stateName        AZ
# Name: 3331, dtype: object
# garbage present with index2 3426
# postalCode      85001
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 3426, dtype: object
# garbage present with index2 3452
# postalCode        61820
# streetAddr          NaN
# cityName      Champaign
# stateName            IL
# Name: 3452, dtype: object
# garbage present with index2 3490
# postalCode        89119
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 3490, dtype: object
# garbage present with index2 3496
# postalCode      85234
# streetAddr        NaN
# cityName      Gilbert
# stateName          AZ
# Name: 3496, dtype: object
# garbage present with index2 3503
# postalCode              89030
# streetAddr                NaN
# cityName      North Las Vegas
# stateName                  NV
# Name: 3503, dtype: object
# garbage present with index2 3572
# postalCode              89086
# streetAddr                NaN
# cityName      North Las Vegas
# stateName                  NV
# Name: 3572, dtype: object
# garbage present with index2 3620
# postalCode         85254
# streetAddr           NaN
# cityName      Scottsdale
# stateName             AZ
# Name: 3620, dtype: object
# garbage present with index2 3638
# postalCode    M4E 2E1
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 3638, dtype: object
# garbage present with index2 3653
# postalCode         15230
# streetAddr           NaN
# cityName      Pittsburgh
# stateName             PA
# Name: 3653, dtype: object
# garbage present with index2 3701
# postalCode         15203
# streetAddr           NaN
# cityName      Pittsburgh
# stateName             PA
# Name: 3701, dtype: object
# garbage present with index2 3770
# postalCode              89081
# streetAddr                NaN
# cityName      North Las Vegas
# stateName                  NV
# Name: 3770, dtype: object
# garbage present with index2 3781
# postalCode      85085
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 3781, dtype: object
# garbage present with index2 3837
# postalCode      53706
# streetAddr        NaN
# cityName      Madison
# stateName          WI
# Name: 3837, dtype: object
# garbage present with index2 3883
# postalCode         85255
# streetAddr           NaN
# cityName      Scottsdale
# stateName             AZ
# Name: 3883, dtype: object
# garbage present with index2 3899
# postalCode              89032
# streetAddr                NaN
# cityName      North Las Vegas
# stateName                  NV
# Name: 3899, dtype: object
# garbage present with index2 3938
# postalCode         15237
# streetAddr           NaN
# cityName      Pittsburgh
# stateName             PA
# Name: 3938, dtype: object
# garbage present with index2 3948
# postalCode         85266
# streetAddr           NaN
# cityName      Scottsdale
# stateName             AZ
# Name: 3948, dtype: object
# garbage present with index2 4003
# postalCode       85379
# streetAddr         NaN
# cityName      Surprise
# stateName           AZ
# Name: 4003, dtype: object
# garbage present with index2 4004
# postalCode        89141
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 4004, dtype: object
# garbage present with index2 4050
# postalCode         15207
# streetAddr           NaN
# cityName      Pittsburgh
# stateName             PA
# Name: 4050, dtype: object
# garbage present with index2 4125
# postalCode         85262
# streetAddr           NaN
# cityName      Scottsdale
# stateName             AZ
# Name: 4125, dtype: object
# garbage present with index2 4162
# postalCode    85213
# streetAddr      NaN
# cityName       Mesa
# stateName        AZ
# Name: 4162, dtype: object
# garbage present with index2 4163
# postalCode      85298
# streetAddr        NaN
# cityName      Gilbert
# stateName          AZ
# Name: 4163, dtype: object
# garbage present with index2 4234
# postalCode        61821
# streetAddr          NaN
# cityName      Champaign
# stateName            IL
# Name: 4234, dtype: object
# garbage present with index2 4243
# postalCode       85374
# streetAddr         NaN
# cityName      Surprise
# stateName           AZ
# Name: 4243, dtype: object
# garbage present with index2 4248
# postalCode         85260
# streetAddr           NaN
# cityName      Scottsdale
# stateName             AZ
# Name: 4248, dtype: object
# garbage present with index2 4255
# postalCode        89145
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 4255, dtype: object
# garbage present with index2 4261
# postalCode        89157
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 4261, dtype: object
# garbage present with index2 4262
# postalCode             85268
# streetAddr               NaN
# cityName      Fountain Hills
# stateName                 AZ
# Name: 4262, dtype: object
# garbage present with index2 4264
# postalCode      28012
# streetAddr        NaN
# cityName      Belmont
# stateName          NC
# Name: 4264, dtype: object
# garbage present with index2 4308
# postalCode    85203
# streetAddr      NaN
# cityName       Mesa
# stateName        AZ
# Name: 4308, dtype: object
# garbage present with index2 4393
# postalCode      85296
# streetAddr        NaN
# cityName      Gilbert
# stateName          AZ
# Name: 4393, dtype: object
# garbage present with index2 4410
# postalCode      85051
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 4410, dtype: object
# garbage present with index2 4526
# postalCode      85041
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 4526, dtype: object
# garbage present with index2 4533
# postalCode       85224
# streetAddr         NaN
# cityName      Chandler
# stateName           AZ
# Name: 4533, dtype: object
# garbage present with index2 4540
# postalCode                 85005
# streetAddr                   NaN
# cityName      Phoenix Metro Area
# stateName                     AZ
# Name: 4540, dtype: object
# garbage present with index2 4550
# postalCode      85004
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 4550, dtype: object
# garbage present with index2 4569
# postalCode      85053
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 4569, dtype: object
# garbage present with index2 4608
# postalCode        44113
# streetAddr          NaN
# cityName      Cleveland
# stateName            OH
# Name: 4608, dtype: object
# garbage present with index2 4609
# postalCode      85042
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 4609, dtype: object
# garbage present with index2 4613
# postalCode        53711
# streetAddr          NaN
# cityName      Fitchburg
# stateName            WI
# Name: 4613, dtype: object
# garbage present with index2 4660
# postalCode        89123
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 4660, dtype: object
# garbage present with index2 4672
# postalCode      53713
# streetAddr        NaN
# cityName      Madison
# stateName          WI
# Name: 4672, dtype: object
# garbage present with index2 4688
# postalCode    M5S 3C9
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 4688, dtype: object
# garbage present with index2 4742
# postalCode         15212
# streetAddr           NaN
# cityName      Pittsburgh
# stateName             PA
# Name: 4742, dtype: object
# garbage present with index2 4799
# postalCode     28173
# streetAddr       NaN
# cityName      Waxhaw
# stateName         NC
# Name: 4799, dtype: object
# garbage present with index2 4819
# postalCode          NaN
# streetAddr          NaN
# cityName      Champaign
# stateName            IL
# Name: 4819, dtype: object
# garbage present with index2 4863
# postalCode    M5T 1K6
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 4863, dtype: object
# garbage present with index2 4870
# postalCode      85308
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 4870, dtype: object
# garbage present with index2 4878
# postalCode    M6K 3J1
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 4878, dtype: object
# garbage present with index2 4883
# postalCode       85310
# streetAddr         NaN
# cityName      Glendale
# stateName           AZ
# Name: 4883, dtype: object
# garbage present with index2 4998
# postalCode    M5B 2H1
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 4998, dtype: object
# garbage present with index2 5057
# postalCode      85006
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 5057, dtype: object
# garbage present with index2 5063
# postalCode           NaN
# streetAddr           NaN
# cityName      Scottsdale
# stateName             AZ
# Name: 5063, dtype: object
# garbage present with index2 5096
# postalCode         NaN
# streetAddr         NaN
# cityName      Montréal
# stateName           QC
# Name: 5096, dtype: object
# garbage present with index2 5112
# postalCode       85307
# streetAddr         NaN
# cityName      Glendale
# stateName           AZ
# Name: 5112, dtype: object
# garbage present with index2 5126
# postalCode          15146
# streetAddr            NaN
# cityName      Monroeville
# stateName              PA
# Name: 5126, dtype: object
# garbage present with index2 5238
# postalCode        89146
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 5238, dtype: object
# garbage present with index2 5264
# postalCode    M5G 2A7
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 5264, dtype: object
# garbage present with index2 5277
# postalCode     85381
# streetAddr       NaN
# cityName      Peoria
# stateName         AZ
# Name: 5277, dtype: object
# garbage present with index2 5321
# postalCode        28216
# streetAddr          NaN
# cityName      Charlotte
# stateName            NC
# Name: 5321, dtype: object
# garbage present with index2 5362
# postalCode           89005
# streetAddr             NaN
# cityName      Boulder City
# stateName               NV
# Name: 5362, dtype: object
# garbage present with index2 5412
# postalCode           28079
# streetAddr             NaN
# cityName      Indian Trail
# stateName               NC
# Name: 5412, dtype: object
# garbage present with index2 5545
# postalCode         15243
# streetAddr           NaN
# cityName      Pittsburgh
# stateName             PA
# Name: 5545, dtype: object
# garbage present with index2 5573
# postalCode      85013
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 5573, dtype: object
# garbage present with index2 5583
# postalCode        89183
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 5583, dtype: object
# garbage present with index2 5621
# postalCode        89110
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 5621, dtype: object
# garbage present with index2 5656
# postalCode      53711
# streetAddr        NaN
# cityName      Madison
# stateName          WI
# Name: 5656, dtype: object
# garbage present with index2 5735
# postalCode      85086
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 5735, dtype: object
# garbage present with index2 5766
# postalCode    85281
# streetAddr      NaN
# cityName      Tempe
# stateName        AZ
# Name: 5766, dtype: object
# garbage present with index2 5801
# postalCode      85233
# streetAddr        NaN
# cityName      Gilbert
# stateName          AZ
# Name: 5801, dtype: object
# garbage present with index2 5863
# postalCode      85034
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 5863, dtype: object
# garbage present with index2 5906
# postalCode        L5V 2K6
# streetAddr            NaN
# cityName      Mississauga
# stateName              ON
# Name: 5906, dtype: object
# garbage present with index2 6122
# postalCode       85372
# streetAddr         NaN
# cityName      Sun City
# stateName           AZ
# Name: 6122, dtype: object
# garbage present with index2 6165
# postalCode        89135
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 6165, dtype: object
# garbage present with index2 6226
# postalCode         NaN
# streetAddr         NaN
# cityName      Glendale
# stateName           AZ
# Name: 6226, dtype: object
# garbage present with index2 6234
# postalCode        28227
# streetAddr          NaN
# cityName      Mint Hill
# stateName            NC
# Name: 6234, dtype: object
# garbage present with index2 6268
# postalCode      85015
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 6268, dtype: object
# garbage present with index2 6305
# postalCode        44101
# streetAddr          NaN
# cityName      Cleveland
# stateName            OH
# Name: 6305, dtype: object
# garbage present with index2 6326
# postalCode    M5S 2M6
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 6326, dtype: object
# garbage present with index2 6398
# postalCode    85282
# streetAddr      NaN
# cityName      Tempe
# stateName        AZ
# Name: 6398, dtype: object
# garbage present with index2 6427
# postalCode        28208
# streetAddr          NaN
# cityName      Charlotte
# stateName            NC
# Name: 6427, dtype: object
# garbage present with index2 6443
# postalCode       NaN
# streetAddr       NaN
# cityName      Laveen
# stateName         AZ
# Name: 6443, dtype: object
# garbage present with index2 6469
# postalCode    M6P 3K7
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 6469, dtype: object
# garbage present with index2 6537
# postalCode         85054
# streetAddr           NaN
# cityName      Scottsdale
# stateName             AZ
# Name: 6537, dtype: object
# garbage present with index2 6626
# postalCode    85280
# streetAddr      NaN
# cityName      Tempe
# stateName        AZ
# Name: 6626, dtype: object
# garbage present with index2 6661
# postalCode      85043
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 6661, dtype: object
# garbage present with index2 6748
# postalCode       44145
# streetAddr         NaN
# cityName      Westlake
# stateName           OH
# Name: 6748, dtype: object
# garbage present with index2 6756
# postalCode        89052
# streetAddr          NaN
# cityName      Henderson
# stateName            NV
# Name: 6756, dtype: object
# garbage present with index2 6765
# postalCode        89074
# streetAddr          NaN
# cityName      Henderson
# stateName            NV
# Name: 6765, dtype: object
# garbage present with index2 6776
# postalCode    85260
# streetAddr      NaN
# cityName       Mesa
# stateName        AZ
# Name: 6776, dtype: object
# garbage present with index2 6812
# postalCode         15238
# streetAddr           NaN
# cityName      Pittsburgh
# stateName             PA
# Name: 6812, dtype: object
# garbage present with index2 6892
# postalCode       85302
# streetAddr         NaN
# cityName      Glendale
# stateName           AZ
# Name: 6892, dtype: object
# garbage present with index2 6914
# postalCode       85323
# streetAddr         NaN
# cityName      Avondale
# stateName           AZ
# Name: 6914, dtype: object
# garbage present with index2 7062
# postalCode             85269
# streetAddr               NaN
# cityName      Fountain Hills
# stateName                 AZ
# Name: 7062, dtype: object
# garbage present with index2 7130
# postalCode         85258
# streetAddr           NaN
# cityName      Scottsdale
# stateName             AZ
# Name: 7130, dtype: object
# garbage present with index2 7134
# postalCode       85353
# streetAddr         NaN
# cityName      Tolleson
# stateName           AZ
# Name: 7134, dtype: object
# garbage present with index2 7170
# postalCode              85340
# streetAddr                NaN
# cityName      Litchfield Park
# stateName                  AZ
# Name: 7170, dtype: object
# garbage present with index2 7319
# postalCode     85382
# streetAddr       NaN
# cityName      Peoria
# stateName         AZ
# Name: 7319, dtype: object
# garbage present with index2 7325
# postalCode       85225
# streetAddr         NaN
# cityName      Chandler
# stateName           AZ
# Name: 7325, dtype: object
# garbage present with index2 7467
# postalCode        28226
# streetAddr          NaN
# cityName      Charlotte
# stateName            NC
# Name: 7467, dtype: object
# garbage present with index2 7701
# postalCode      85023
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 7701, dtype: object
# garbage present with index2 7774
# postalCode     85383
# streetAddr       NaN
# cityName      Peoria
# stateName         AZ
# Name: 7774, dtype: object
# garbage present with index2 7784
# postalCode        T3H
# streetAddr        NaN
# cityName      Calgary
# stateName          AB
# Name: 7784, dtype: object
# garbage present with index2 7861
# postalCode    T1X 0L3
# streetAddr        NaN
# cityName      Calgary
# stateName          AB
# Name: 7861, dtype: object
# garbage present with index2 7865
# postalCode        44103
# streetAddr          NaN
# cityName      Cleveland
# stateName            OH
# Name: 7865, dtype: object
# garbage present with index2 7881
# postalCode      85024
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 7881, dtype: object
# garbage present with index2 7903
# postalCode        89031
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 7903, dtype: object
# garbage present with index2 7920
# postalCode         15109
# streetAddr           NaN
# cityName      Pittsburgh
# stateName             PA
# Name: 7920, dtype: object
# garbage present with index2 7930
# postalCode    M6J 0B8
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 7930, dtype: object
# garbage present with index2 7969
# postalCode      85044
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 7969, dtype: object
# garbage present with index2 8040
# postalCode    M4Y 1Z9
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 8040, dtype: object
# garbage present with index2 8070
# postalCode    44129
# streetAddr      NaN
# cityName      Parma
# stateName        OH
# Name: 8070, dtype: object
# garbage present with index2 8111
# postalCode     85345
# streetAddr       NaN
# cityName      Peoria
# stateName         AZ
# Name: 8111, dtype: object
# garbage present with index2 8247
# postalCode       28105
# streetAddr         NaN
# cityName      Matthews
# stateName           NC
# Name: 8247, dtype: object
# garbage present with index2 8305
# postalCode        NaN
# streetAddr        NaN
# cityName      Madison
# stateName          WI
# Name: 8305, dtype: object
# garbage present with index2 8332
# postalCode        89178
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 8332, dtype: object
# garbage present with index2 8449
# postalCode        89107
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 8449, dtype: object
# garbage present with index2 8461
# postalCode     H1V 3N7
# streetAddr         NaN
# cityName      Montréal
# stateName           QC
# Name: 8461, dtype: object
# garbage present with index2 8499
# postalCode    M3A 2Y7
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 8499, dtype: object
# garbage present with index2 8546
# postalCode    85210
# streetAddr      NaN
# cityName       Mesa
# stateName        AZ
# Name: 8546, dtype: object
# garbage present with index2 8590
# postalCode          NaN
# streetAddr          NaN
# cityName      Charlotte
# stateName            NC
# Name: 8590, dtype: object
# garbage present with index2 8780
# postalCode        89124
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 8780, dtype: object
# garbage present with index2 8801
# postalCode        89160
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 8801, dtype: object
# garbage present with index2 8845
# postalCode        28202
# streetAddr          NaN
# cityName      Charlotte
# stateName            NC
# Name: 8845, dtype: object
# garbage present with index2 9089
# postalCode               85005
# streetAddr                 NaN
# cityName      Estrella Village
# stateName                   AZ
# Name: 9089, dtype: object
# garbage present with index2 9184
# postalCode    M5C 2W5
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 9184, dtype: object
# garbage present with index2 9269
# postalCode      85022
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 9269, dtype: object
# garbage present with index2 9278
# postalCode        89015
# streetAddr          NaN
# cityName      Henderson
# stateName            NV
# Name: 9278, dtype: object
# garbage present with index2 9287
# postalCode      85297
# streetAddr        NaN
# cityName      Gilbert
# stateName          AZ
# Name: 9287, dtype: object
# garbage present with index2 9311
# postalCode    T1Y 4M1
# streetAddr        NaN
# cityName      Calgary
# stateName          AB
# Name: 9311, dtype: object
# garbage present with index2 9392
# postalCode       85373
# streetAddr         NaN
# cityName      Sun City
# stateName           AZ
# Name: 9392, dtype: object
# garbage present with index2 9393
# postalCode      85027
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 9393, dtype: object
# garbage present with index2 9399
# postalCode            15636
# streetAddr              NaN
# cityName      Harrison City
# stateName                PA
# Name: 9399, dtype: object
# garbage present with index2 9494
# postalCode     61801
# streetAddr       NaN
# cityName      Urbana
# stateName         IL
# Name: 9494, dtype: object
# garbage present with index2 9579
# postalCode        89105
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 9579, dtype: object
# garbage present with index2 9608
# postalCode        88905
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 9608, dtype: object
# garbage present with index2 9642
# postalCode        89016
# streetAddr          NaN
# cityName      Henderson
# stateName            NV
# Name: 9642, dtype: object
# garbage present with index2 9759
# postalCode      53719
# streetAddr        NaN
# cityName      Madison
# stateName          WI
# Name: 9759, dtype: object
# garbage present with index2 9860
# postalCode      85080
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 9860, dtype: object
# garbage present with index2 9894
# postalCode    T2W 3L6
# streetAddr        NaN
# cityName      Calgary
# stateName          AB
# Name: 9894, dtype: object
# garbage present with index2 10047
# postalCode    44240
# streetAddr      NaN
# cityName       Kent
# stateName        OH
# Name: 10047, dtype: object
# garbage present with index2 10073
# postalCode               44125
# streetAddr                 NaN
# cityName      Garfield Heights
# stateName                   OH
# Name: 10073, dtype: object
# garbage present with index2 10149
# postalCode        89030
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 10149, dtype: object
# garbage present with index2 10151
# postalCode        89002
# streetAddr          NaN
# cityName      Henderson
# stateName            NV
# Name: 10151, dtype: object
# garbage present with index2 10226
# postalCode        28277
# streetAddr          NaN
# cityName      Charlotte
# stateName            NC
# Name: 10226, dtype: object
# garbage present with index2 10281
# postalCode                H9B 1A2
# streetAddr                    NaN
# cityName      Dollard-des Ormeaux
# stateName                      QC
# Name: 10281, dtype: object
# garbage present with index2 10310
# postalCode        15030
# streetAddr          NaN
# cityName      Creighton
# stateName            PA
# Name: 10310, dtype: object
# garbage present with index2 10327
# postalCode        89014
# streetAddr          NaN
# cityName      Henderson
# stateName            NV
# Name: 10327, dtype: object
# garbage present with index2 10423
# postalCode        28269
# streetAddr          NaN
# cityName      Charlotte
# stateName            NC
# Name: 10423, dtype: object
# garbage present with index2 10462
# postalCode         15217
# streetAddr           NaN
# cityName      Pittsburgh
# stateName             PA
# Name: 10462, dtype: object
# garbage present with index2 10885
# postalCode      85008
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 10885, dtype: object
# garbage present with index2 10944
# postalCode      85029
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 10944, dtype: object
# garbage present with index2 11006
# postalCode     61803
# streetAddr       NaN
# cityName      Urbana
# stateName         IL
# Name: 11006, dtype: object
# garbage present with index2 11086
# postalCode       85338
# streetAddr         NaN
# cityName      Goodyear
# stateName           AZ
# Name: 11086, dtype: object
# garbage present with index2 11210
# postalCode              85253
# streetAddr                NaN
# cityName      Paradise Valley
# stateName                  AZ
# Name: 11210, dtype: object
# garbage present with index2 11230
# postalCode       85248
# streetAddr         NaN
# cityName      Chandler
# stateName           AZ
# Name: 11230, dtype: object
# garbage present with index2 11293
# postalCode        44012
# streetAddr          NaN
# cityName      Avon Lake
# stateName            OH
# Name: 11293, dtype: object
# garbage present with index2 11497
# postalCode    M4P 1E4
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 11497, dtype: object
# garbage present with index2 11641
# postalCode    85296
# streetAddr      NaN
# cityName       Mesa
# stateName        AZ
# Name: 11641, dtype: object
# garbage present with index2 11644
# postalCode        89139
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 11644, dtype: object
# garbage present with index2 11795
# postalCode        85335
# streetAddr          NaN
# cityName      El Mirage
# stateName            AZ
# Name: 11795, dtype: object
# garbage present with index2 11926
# postalCode        89133
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 11926, dtype: object
# garbage present with index2 12008
# postalCode            44022
# streetAddr              NaN
# cityName      Chagrin Falls
# stateName                OH
# Name: 12008, dtype: object
# garbage present with index2 12057
# postalCode    M4X 1L9
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 12057, dtype: object
# garbage present with index2 12146
# postalCode       15106
# streetAddr         NaN
# cityName      Carnegie
# stateName           PA
# Name: 12146, dtype: object
# garbage present with index2 12318
# postalCode    T3A 3S4
# streetAddr        NaN
# cityName      Calgary
# stateName          AB
# Name: 12318, dtype: object
# garbage present with index2 12376
# postalCode     H4B 2K8
# streetAddr         NaN
# cityName      Montréal
# stateName           QC
# Name: 12376, dtype: object
# garbage present with index2 12390
# postalCode       85304
# streetAddr         NaN
# cityName      Glendale
# stateName           AZ
# Name: 12390, dtype: object
# garbage present with index2 12525
# postalCode    M5V 3M3
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 12525, dtype: object
# garbage present with index2 12543
# postalCode        M2N
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 12543, dtype: object
# garbage present with index2 12642
# postalCode        89032
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 12642, dtype: object
# garbage present with index2 12699
# postalCode    L5M 4Z5
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 12699, dtype: object
# garbage present with index2 12754
# postalCode      44001
# streetAddr        NaN
# cityName      Amherst
# stateName          OH
# Name: 12754, dtype: object
# garbage present with index2 12965
# postalCode         85256
# streetAddr           NaN
# cityName      Scottsdale
# stateName             AZ
# Name: 12965, dtype: object
# garbage present with index2 13032
# postalCode        44115
# streetAddr          NaN
# cityName      Cleveland
# stateName            OH
# Name: 13032, dtype: object
# garbage present with index2 13054
# postalCode        89108
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 13054, dtype: object
# garbage present with index2 13115
# postalCode           28078
# streetAddr             NaN
# cityName      Huntersville
# stateName               NC
# Name: 13115, dtype: object
# garbage present with index2 13128
# postalCode              89033
# streetAddr                NaN
# cityName      North Las Vegas
# stateName                  NV
# Name: 13128, dtype: object
# garbage present with index2 13140
# postalCode        89004
# streetAddr          NaN
# cityName      Summerlin
# stateName            NV
# Name: 13140, dtype: object
# garbage present with index2 13189
# postalCode      85259
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 13189, dtype: object
# garbage present with index2 13281
# postalCode    M5X 2A2
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 13281, dtype: object
# garbage present with index2 13342
# postalCode         15222
# streetAddr           NaN
# cityName      Pittsburgh
# stateName             PA
# Name: 13342, dtype: object
# garbage present with index2 13578
# postalCode     85385
# streetAddr       NaN
# cityName      Peoria
# stateName         AZ
# Name: 13578, dtype: object
# garbage present with index2 13582
# postalCode        M4B
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 13582, dtype: object
# garbage present with index2 13612
# postalCode      85083
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 13612, dtype: object
# garbage present with index2 13698
# postalCode    M4N 2L4
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 13698, dtype: object
# garbage present with index2 13886
# postalCode        28299
# streetAddr          NaN
# cityName      Charlotte
# stateName            NC
# Name: 13886, dtype: object
# garbage present with index2 13976
# postalCode    M4B 1B3
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 13976, dtype: object
# garbage present with index2 13984
# postalCode      85017
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 13984, dtype: object
# garbage present with index2 14012
# postalCode    T2P 2G7
# streetAddr        NaN
# cityName      Calgary
# stateName          AB
# Name: 14012, dtype: object
# garbage present with index2 14059
# postalCode    M4E 3P2
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 14059, dtype: object
# garbage present with index2 14145
# postalCode        44109
# streetAddr          NaN
# cityName      Cleveland
# stateName            OH
# Name: 14145, dtype: object
# garbage present with index2 14337
# postalCode        44124
# streetAddr          NaN
# cityName      Cleveland
# stateName            OH
# Name: 14337, dtype: object
# garbage present with index2 14372
# postalCode      85203
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 14372, dtype: object
# garbage present with index2 14419
# postalCode      85010
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 14419, dtype: object
# garbage present with index2 14579
# postalCode     H8N 1V2
# streetAddr         NaN
# cityName      Montréal
# stateName           QC
# Name: 14579, dtype: object
# garbage present with index2 14643
# postalCode        L3R
# streetAddr        NaN
# cityName      Markham
# stateName          ON
# Name: 14643, dtype: object
# garbage present with index2 14759
# postalCode         85267
# streetAddr           NaN
# cityName      Scottsdale
# stateName             AZ
# Name: 14759, dtype: object
# garbage present with index2 14961
# postalCode    M2J 4R4
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 14961, dtype: object
# garbage present with index2 15025
# postalCode            15068
# streetAddr              NaN
# cityName      Lower Burrell
# stateName                PA
# Name: 15025, dtype: object
# garbage present with index2 15096
# postalCode    85226
# streetAddr      NaN
# cityName      Tempe
# stateName        AZ
# Name: 15096, dtype: object
# garbage present with index2 15179
# postalCode        28278
# streetAddr          NaN
# cityName      Charlotte
# stateName            NC
# Name: 15179, dtype: object
# garbage present with index2 15205
# postalCode     85236
# streetAddr       NaN
# cityName      Higley
# stateName         AZ
# Name: 15205, dtype: object
# garbage present with index2 15259
# postalCode      85030
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 15259, dtype: object
# garbage present with index2 15261
# postalCode        28134
# streetAddr          NaN
# cityName      Pineville
# stateName            NC
# Name: 15261, dtype: object
# garbage present with index2 15305
# postalCode      53703
# streetAddr        NaN
# cityName      Madison
# stateName          WI
# Name: 15305, dtype: object
# garbage present with index2 15380
# postalCode         NaN
# streetAddr         NaN
# cityName      Surprise
# stateName           AZ
# Name: 15380, dtype: object
# garbage present with index2 15408
# postalCode        M6N
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 15408, dtype: object
# garbage present with index2 15428
# postalCode     H2L 0C7
# streetAddr         NaN
# cityName      Montréal
# stateName           QC
# Name: 15428, dtype: object
# garbage present with index2 15471
# postalCode    M5V 1A2
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 15471, dtype: object
# garbage present with index2 15621
# postalCode    T2E 7B9
# streetAddr        NaN
# cityName      Calgary
# stateName          AB
# Name: 15621, dtype: object
# garbage present with index2 15852
# postalCode          44124
# streetAddr            NaN
# cityName      Pepper Pike
# stateName              OH
# Name: 15852, dtype: object
# garbage present with index2 16133
# postalCode         15211
# streetAddr           NaN
# cityName      Pittsburgh
# stateName             PA
# Name: 16133, dtype: object
# garbage present with index2 16345
# postalCode        89015
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 16345, dtype: object
# garbage present with index2 16373
# postalCode      53705
# streetAddr        NaN
# cityName      Madison
# stateName          WI
# Name: 16373, dtype: object
# garbage present with index2 16455
# postalCode    M4Y 1N7
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 16455, dtype: object
# garbage present with index2 16691
# postalCode    85206
# streetAddr      NaN
# cityName       Mesa
# stateName        AZ
# Name: 16691, dtype: object
# garbage present with index2 16797
# postalCode         15106
# streetAddr           NaN
# cityName      Pittsburgh
# stateName             PA
# Name: 16797, dtype: object
# garbage present with index2 16854
# postalCode         15205
# streetAddr           NaN
# cityName      Pittsburgh
# stateName             PA
# Name: 16854, dtype: object
# garbage present with index2 16866
# postalCode     H2Y 2E2
# streetAddr         NaN
# cityName      Montréal
# stateName           QC
# Name: 16866, dtype: object
# garbage present with index2 16871
# postalCode        M5V
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 16871, dtype: object
# garbage present with index2 16926
# postalCode      28025
# streetAddr        NaN
# cityName      Concord
# stateName          NC
# Name: 16926, dtype: object
# garbage present with index2 16935
# postalCode         28210
# streetAddr           NaN
# cityName      charlottte
# stateName             NC
# Name: 16935, dtype: object
# garbage present with index2 16941
# postalCode    T1Y 1K7
# ...
# cityName      Phoenix
# stateName          AZ
# Name: 162713, dtype: object
# garbage present with index2 162832
# postalCode       L6G 0B9
# streetAddr           NaN
# cityName      Unionville
# stateName             ON
# Name: 162832, dtype: object
# garbage present with index2 162953
# postalCode        L4X 2G9
# streetAddr            NaN
# cityName      Mississauga
# stateName              ON
# Name: 162953, dtype: object
# garbage present with index2 163252
# postalCode    T2N 0S6
# streetAddr        NaN
# cityName      Calgary
# stateName          AB
# Name: 163252, dtype: object
# garbage present with index2 163425
# postalCode              89149
# streetAddr                NaN
# cityName      North Las Vegas
# stateName                  NV
# Name: 163425, dtype: object
# garbage present with index2 163964
# postalCode    85016
# streetAddr      NaN
# cityName      Tempe
# stateName        AZ
# Name: 163964, dtype: object
# garbage present with index2 164015
# postalCode      65241
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 164015, dtype: object
# garbage present with index2 164663
# postalCode    T2J 6P9
# streetAddr        NaN
# cityName      Calgary
# stateName          AB
# Name: 164663, dtype: object
# garbage present with index2 164809
# postalCode          53572
# streetAddr            NaN
# cityName      Mount Horeb
# stateName              WI
# Name: 164809, dtype: object
# garbage present with index2 165197
# postalCode    44210
# streetAddr      NaN
# cityName       Bath
# stateName        OH
# Name: 165197, dtype: object
# garbage present with index2 165328
# postalCode        89138
# streetAddr          NaN
# cityName      Summerlin
# stateName            NV
# Name: 165328, dtype: object
# garbage present with index2 165384
# postalCode    T2E 7K6
# streetAddr        NaN
# cityName      Calgary
# stateName          AB
# Name: 165384, dtype: object
# garbage present with index2 165541
# postalCode      85061
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 165541, dtype: object
# garbage present with index2 165573
# postalCode        M9A
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 165573, dtype: object
# garbage present with index2 166078
# postalCode    M5V 2L3
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 166078, dtype: object
# garbage present with index2 166190
# postalCode         15218
# streetAddr           NaN
# cityName      Pittsburgh
# stateName             PA
# Name: 166190, dtype: object
# garbage present with index2 166233
# postalCode    M5A 2S4
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 166233, dtype: object
# garbage present with index2 166320
# postalCode        T2Z
# streetAddr        NaN
# cityName      Calgary
# stateName          AB
# Name: 166320, dtype: object
# garbage present with index2 166640
# postalCode        89115
# streetAddr          NaN
# cityName      Las vegas
# stateName            NV
# Name: 166640, dtype: object
# garbage present with index2 167226
# postalCode         NaN
# streetAddr         NaN
# cityName      Goodyear
# stateName           AZ
# Name: 167226, dtype: object
# garbage present with index2 167497
# postalCode    T3G 4P8
# streetAddr        NaN
# cityName      Calgary
# stateName          AB
# Name: 167497, dtype: object
# garbage present with index2 168151
# postalCode        M5G
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 168151, dtype: object
# garbage present with index2 168318
# postalCode    M9W 2Z2
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 168318, dtype: object
# garbage present with index2 168599
# postalCode        M4X
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 168599, dtype: object
# garbage present with index2 168732
# postalCode    M6P 3S9
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 168732, dtype: object
# garbage present with index2 169243
# postalCode        44122
# streetAddr          NaN
# cityName      Cleveland
# stateName            OH
# Name: 169243, dtype: object
# garbage present with index2 169594
# postalCode         NaN
# streetAddr         NaN
# cityName      Carnegie
# stateName           PA
# Name: 169594, dtype: object
# garbage present with index2 169725
# postalCode        L5M 2G6
# streetAddr            NaN
# cityName      Mississauga
# stateName              ON
# Name: 169725, dtype: object
# garbage present with index2 170214
# postalCode       85382
# streetAddr         NaN
# cityName      Surprise
# stateName           AZ
# Name: 170214, dtype: object
# garbage present with index2 170403
# postalCode        L5G 4S4
# streetAddr            NaN
# cityName      Mississauga
# stateName              ON
# Name: 170403, dtype: object
# garbage present with index2 170514
# postalCode         NaN
# streetAddr         NaN
# cityName      Avondale
# stateName           AZ
# Name: 170514, dtype: object
# garbage present with index2 170930
# postalCode       L1N
# streetAddr       NaN
# cityName      Whitby
# stateName         ON
# Name: 170930, dtype: object
# garbage present with index2 170967
# postalCode      85002
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 170967, dtype: object
# garbage present with index2 171122
# postalCode    T2R 1M7
# streetAddr        NaN
# cityName      Calgary
# stateName          AB
# Name: 171122, dtype: object
# garbage present with index2 171524
# postalCode        NaN
# streetAddr        NaN
# cityName      Airdrie
# stateName          AB
# Name: 171524, dtype: object
# garbage present with index2 171779
# postalCode        89139
# streetAddr          NaN
# cityName      Las Vegas
# stateName            CA
# Name: 171779, dtype: object
# garbage present with index2 171933
# postalCode    M6P 1B2
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 171933, dtype: object
# garbage present with index2 172415
# postalCode    M5S 1X6
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 172415, dtype: object
# garbage present with index2 172804
# postalCode        44178
# streetAddr          NaN
# cityName      Cleveland
# stateName            OH
# Name: 172804, dtype: object
# garbage present with index2 172814
# postalCode        M5V
# streetAddr        NaN
# cityName      toronto
# stateName          ON
# Name: 172814, dtype: object
# garbage present with index2 173154
# postalCode        44050
# streetAddr          NaN
# cityName      Cleveland
# stateName            OH
# Name: 173154, dtype: object
# garbage present with index2 173300
# postalCode    T1X 1E1
# streetAddr        NaN
# cityName      Calgary
# stateName          AB
# Name: 173300, dtype: object
# garbage present with index2 173371
# postalCode         15021
# streetAddr           NaN
# cityName      Pittsburgh
# stateName             PA
# Name: 173371, dtype: object
# garbage present with index2 173392
# postalCode    M9V 1V9
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 173392, dtype: object
# garbage present with index2 173765
# postalCode     T1X 0L3
# streetAddr         NaN
# cityName      Beltline
# stateName           AB
# Name: 173765, dtype: object
# garbage present with index2 173878
# postalCode    M5G 2C4
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 173878, dtype: object
# garbage present with index2 174011
# postalCode      85201
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 174011, dtype: object
# garbage present with index2 174624
# postalCode    M2J 4R3
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 174624, dtype: object
# garbage present with index2 175034
# postalCode    M9N 2K3
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 175034, dtype: object
# garbage present with index2 175039
# postalCode      L4J 1W4
# streetAddr          NaN
# cityName      Thornhill
# stateName            ON
# Name: 175039, dtype: object
# garbage present with index2 175372
# postalCode    T3H 3S7
# streetAddr        NaN
# cityName      Calgary
# stateName          AB
# Name: 175372, dtype: object
# garbage present with index2 175760
# postalCode              89141
# streetAddr                NaN
# cityName      North Las Vegas
# stateName                  NV
# Name: 175760, dtype: object
# garbage present with index2 175833
# postalCode      85258
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 175833, dtype: object
# garbage present with index2 175834
# postalCode        T3M
# streetAddr        NaN
# cityName      Calgary
# stateName          AB
# Name: 175834, dtype: object
# garbage present with index2 176107
# postalCode        L5M 2V8
# streetAddr            NaN
# cityName      Mississauga
# stateName              ON
# Name: 176107, dtype: object
# garbage present with index2 176297
# postalCode        T1Y
# streetAddr        NaN
# cityName      Calgary
# stateName          AB
# Name: 176297, dtype: object
# garbage present with index2 176889
# postalCode        28173
# streetAddr          NaN
# cityName      Charlotte
# stateName            NC
# Name: 176889, dtype: object
# garbage present with index2 176913
# postalCode         89101
# streetAddr           NaN
# cityName      Las  Vegas
# stateName             NV
# Name: 176913, dtype: object
# garbage present with index2 177827
# postalCode      85205
# streetAddr        NaN
# cityName      Gilbert
# stateName          AZ
# Name: 177827, dtype: object
# garbage present with index2 179064
# postalCode    L4X 1V1
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 179064, dtype: object
# garbage present with index2 179283
# postalCode    M5T 1L8
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 179283, dtype: object
# garbage present with index2 180517
# postalCode         89141
# streetAddr           NaN
# cityName      Enterprise
# stateName             NV
# Name: 180517, dtype: object
# garbage present with index2 180785
# postalCode        48374
# streetAddr          NaN
# cityName      Los Vegas
# stateName            NV
# Name: 180785, dtype: object
# garbage present with index2 181102
# postalCode        44145
# streetAddr          NaN
# cityName      Cleveland
# stateName            OH
# Name: 181102, dtype: object
# garbage present with index2 181351
# postalCode            L5L
# streetAddr            NaN
# cityName      Mississauga
# stateName              ON
# Name: 181351, dtype: object
# garbage present with index2 181821
# postalCode      85345
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 181821, dtype: object
# garbage present with index2 182198
# postalCode    L4K 5W4
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 182198, dtype: object
# garbage present with index2 182463
# postalCode        44120
# streetAddr          NaN
# cityName      Cleveland
# stateName            OH
# Name: 182463, dtype: object
# garbage present with index2 183073
# postalCode        85208
# streetAddr          NaN
# cityName      East Mesa
# stateName            AZ
# Name: 183073, dtype: object
# garbage present with index2 183163
# postalCode         53558
# streetAddr           NaN
# cityName      Mc Farland
# stateName             WI
# Name: 183163, dtype: object
# garbage present with index2 183995
# postalCode        89002
# streetAddr          NaN
# cityName      HENDERSON
# stateName            NV
# Name: 183995, dtype: object
# garbage present with index2 184342
# postalCode     H2J 2K8
# streetAddr         NaN
# cityName      Montréal
# stateName           QC
# Name: 184342, dtype: object
# garbage present with index2 185049
# postalCode                    H3A 2G4
# streetAddr                        NaN
# cityName      Quartier des Spectacles
# stateName                          QC
# Name: 185049, dtype: object
# garbage present with index2 185096
# postalCode    T3M 1P3
# streetAddr        NaN
# cityName      Calgary
# stateName          AB
# Name: 185096, dtype: object
# garbage present with index2 185294
# postalCode     H9K 1J8
# streetAddr         NaN
# cityName      Montréal
# stateName           QC
# Name: 185294, dtype: object
# garbage present with index2 185325
# postalCode         NaN
# streetAddr         NaN
# cityName      Gastonia
# stateName           NC
# Name: 185325, dtype: object
# garbage present with index2 185622
# postalCode     H1A 1B9
# streetAddr         NaN
# cityName      Montréal
# stateName           QC
# Name: 185622, dtype: object
# garbage present with index2 185704
# postalCode     H3C 1A9
# streetAddr         NaN
# cityName      Montréal
# stateName           QC
# Name: 185704, dtype: object
# garbage present with index2 186114
# postalCode      98112
# streetAddr        NaN
# cityName      Seattle
# stateName          WI
# Name: 186114, dtype: object
# garbage present with index2 186126
# postalCode          M9A
# streetAddr          NaN
# cityName      Etobicoke
# stateName            ON
# Name: 186126, dtype: object
# garbage present with index2 186306
# postalCode             85326
# streetAddr               NaN
# cityName      Rainbow Valley
# stateName                 AZ
# Name: 186306, dtype: object
# garbage present with index2 186366
# postalCode      15071
# streetAddr        NaN
# cityName      Oakdale
# stateName          PA
# Name: 186366, dtype: object
# garbage present with index2 186447
# postalCode        28207
# streetAddr          NaN
# cityName      Charlotte
# stateName            NC
# Name: 186447, dtype: object
# garbage present with index2 187048
# postalCode    M4W 1A7
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 187048, dtype: object
# garbage present with index2 187193
# postalCode    T2C 3M4
# streetAddr        NaN
# cityName      Calgary
# stateName          AB
# Name: 187193, dtype: object
# garbage present with index2 187257
# postalCode    M5R 2S7
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 187257, dtype: object
# garbage present with index2 187304
# postalCode    M2H 1Z8
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 187304, dtype: object
# garbage present with index2 187487
# postalCode     85295
# streetAddr       NaN
# cityName      Higley
# stateName         AZ
# Name: 187487, dtype: object
# garbage present with index2 188678
# postalCode    M6S 5B3
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 188678, dtype: object
# garbage present with index2 188716
# postalCode          NaN
# streetAddr          NaN
# cityName      Newmarket
# stateName            ON
# Name: 188716, dtype: object
# garbage present with index2 188891
# postalCode        44112
# streetAddr          NaN
# cityName      Cleveland
# stateName            OH
# Name: 188891, dtype: object
# garbage present with index2 188987
# postalCode       28036
# streetAddr         NaN
# cityName      Davidson
# stateName           NC
# Name: 188987, dtype: object
# garbage present with index2 189631
# postalCode      85025
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 189631, dtype: object
# garbage present with index2 189736
# postalCode      85304
# streetAddr        NaN
# cityName      Phoenix
# stateName          AZ
# Name: 189736, dtype: object
# garbage present with index2 190135
# postalCode    44234
# streetAddr      NaN
# cityName      Hiram
# stateName        OH
# Name: 190135, dtype: object
# garbage present with index2 190296
# postalCode     L6H 7P8
# streetAddr         NaN
# cityName      Oakville
# stateName           ON
# Name: 190296, dtype: object
# garbage present with index2 190297
# postalCode         85201
# streetAddr           NaN
# cityName      Scottsdale
# stateName             AZ
# Name: 190297, dtype: object
# garbage present with index2 190429
# postalCode        85044
# streetAddr          NaN
# cityName      Ahwatukee
# stateName            AZ
# Name: 190429, dtype: object
# garbage present with index2 190532
# postalCode    M5C 2H4
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 190532, dtype: object
# garbage present with index2 190561
# postalCode    M5E 1W7
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 190561, dtype: object
# garbage present with index2 191185
# postalCode    L6A 0Y3
# streetAddr        NaN
# cityName      Vaughan
# stateName          ON
# Name: 191185, dtype: object
# garbage present with index2 191595
# postalCode    M8Y 1K5
# streetAddr        NaN
# cityName      Toronto
# stateName          ON
# Name: 191595, dtype: object
# garbage present with index2 191727
# postalCode        94085
# streetAddr          NaN
# cityName      Las Vegas
# stateName            NV
# Name: 191727, dtype: object
# done

# %%
dfaddrAB = dfaddrAB.dropna()
dfaddrAB
# Out:
#        postalCode                                streetAddr     cityName  \
# 0           85016               2818 E Camino Acequia Drive      Phoenix
# 1         L5R 3E7                      30 Eglinton Avenue W  Mississauga
# 2         T2R 1L3              1210 8th Street SW, Unit 220      Calgary
# 3           89149               6955 N Durango Dr, Ste 1116    Las Vegas
# 4           85281                         4 E University Dr        Tempe
# ...           ...                                       ...          ...
# 192603      85210                        440 S Extension Rd         Mesa
# 192604    H3B 1A6                521 St. Catherine Street W     Montréal
# 192605    M5B 1V8                       244 Victoria Street      Toronto
# 192606      85044                       10210 South 50th Pl      Phoenix
# 192607      89113  6670 S Tenaya Way, Ste 120, The Body Spa    Las Vegas
#
#        stateName
# 0             AZ
# 1             ON
# 2             AB
# 3             NV
# 4             AZ
# ...          ...
# 192603        AZ
# 192604        QC
# 192605        ON
# 192606        AZ
# 192607        NV
#
# [156260 rows x 4 columns]

# %%
dfaddrAB.to_csv('addressAB.csv', index=False)

# %%
dfcity = pd.DataFrame(df[['city', 'state']])
dfcity
# Out:
#                city state
# 0           Phoenix    AZ
# 1       Mississauga    ON
# 2           Calgary    AB
# 3         Las Vegas    NV
# 4             Tempe    AZ
# ...             ...   ...
# 192604     Montréal    QC
# 192605      Toronto    ON
# 192606      Phoenix    AZ
# 192607    Las Vegas    NV
# 192608       Peoria    AZ
#
# [192609 rows x 2 columns]

# %%
dfcity.rename(columns={'city':'cityName', 'state':'stateName'}, inplace=True)
dfcity.drop_duplicates(keep ='first', inplace = True)
dfcity.to_csv('cityAB.csv', index=False)
dfcity
# Out:
#            cityName stateName
# 0           Phoenix        AZ
# 1       Mississauga        ON
# 2           Calgary        AB
# 3         Las Vegas        NV
# 4             Tempe        AZ
# ...             ...       ...
# 190907      Pahrump        NV
# 191280    ETOBICOKE        ON
# 191517  Rockey View        AB
# 191552   Pittsburch        PA
# 191855  Richmonhill        ON
#
# [1257 rows x 2 columns]

# %%
##################################### dfcity table done ########################################
dfstate = pd.DataFrame(df['state'])
dfstate.drop_duplicates(keep ='first', inplace = True)
dfstate.rename(columns = {'state':'stateName'})
dfstate
# Out:
#        state
# 0         AZ
# 1         ON
# 2         AB
# 3         NV
# 5         NC
# 6         QC
# 15        OH
# 16        PA
# 18        WI
# 91        IL
# 340       SC
# 3461      NY
# 10763     GA
# 12704     TX
# 19506     CA
# 23996     AL
# 30532    DUR
# 36860    XWY
# 40400     TN
# 48744     FL
# 49561    XGM
# 66406     VA
# 66958     CT
# 71461     NJ
# 71562     WA
# 71985     AR
# 72114     UT
# 83036     NM
# 87945    XGL
# 98097    DOW
# 112327   BAS
# 113193    NE
# 117176    AK
# 146687   CON
# 151131    BC
# 174574    VT

# %%
dfstate.to_csv('stateAB.csv', index=False)
