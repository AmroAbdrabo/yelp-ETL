# %%
import pandas as pd
df = pd.read_csv('../../yelpdata/yelp-csv/yelp_academic_dataset_business.csv')
df
# Out:
#                                          address  \
# 0                    2818 E Camino Acequia Drive
# 1                           30 Eglinton Avenue W
# 2                   1210 8th Street SW, Unit 220
# 3                    6955 N Durango Dr, Ste 1116
# 4                              4 E University Dr
# ...                                          ...
# 192604                521 St. Catherine Street W
# 192605                       244 Victoria Street
# 192606                       10210 South 50th Pl
# 192607  6670 S Tenaya Way, Ste 120, The Body Spa
# 192608                 14050 N 83rd Ave, Ste 290
#
#                                                attributes  \
# 0                                                      {}
# 1       {'GoodForMeal': "{'dessert': False, 'latenight...
# 2       {'BusinessParking': "{'garage': False, 'street...
# 3       {'BusinessParking': "{'garage': False, 'street...
# 4                                                      {}
# ...

# %%
dfbusinessAB = pd.DataFrame(df[['business_id','stars', 'review_count', 'name', 'is_open']])
dfbusinessAB
# Out:
#                    business_id  stars  review_count  \
# 0       1SWheh84yJXfytovILXOAQ    3.0             5
# 1       QXAEGFB4oINsVuTFxEYKFQ    2.5           128
# 2       fcXOEZdXYeZqnQ3lGlOXmg    2.0             5
# 3       f2ZWZPENViL92BrFsIgR6w    4.5           116
# 4       6KgGE8B1RsR7jc9R5nuH0Q    2.5             9
# ...                        ...    ...           ...
# 192604  wWV90q48ugyxyXW6gZav8w    3.5            15
# 192605  phSaT3I_y6To1J2OdeFSUQ    4.0            58
# 192606  oU6Q3ymg1Qsh1EUI6oQwQg    2.5             3
# 192607  gdiOk0n7DmNE9w8xeHWkvw    5.0            15
# 192608  Rv8s4io4G4mcUpiDbpzy7w    5.0             3
#
#                                name  is_open
# 0        Arizona Biltmore Golf Club        0
# 1        Emerald Chinese Restaurant        1
# 2       Nucleus Information Service        1
# 3                      Amazing Cuts        1
# 4                      Ruby Tuesday        0
# ...                             ...      ...
# ...

# %%
# just prints done
#import numpy as np
#for index, row in dfbusinessAB.iterrows():
#    if (type(row['stars']) is float and np.isnan(row['stars'])):
#        print('garbage present with index1 '+ str(index))
#        print(str(row))
#    if (type(row['review_count']) is float and np.isnan(row['review_count'])):
#        print('garbage present with index2 '+ str(index))
#        print(str(row))
#    if (type(row['name']) is float and np.isnan(row['name'])):
#        print('garbage present with index3 '+ str(index))
#        print(str(row))
#    if (type(row['is_open']) is float and np.isnan(row['is_open'])):
#        print('garbage present with index4 '+ str(index))
#        print(str(row))
#print('done')

# %%
dfbusinessAB = dfbusinessAB.dropna();
dfbusinessAB
# Out:
#                    business_id  stars  review_count  \
# 0       1SWheh84yJXfytovILXOAQ    3.0             5
# 1       QXAEGFB4oINsVuTFxEYKFQ    2.5           128
# 2       fcXOEZdXYeZqnQ3lGlOXmg    2.0             5
# 3       f2ZWZPENViL92BrFsIgR6w    4.5           116
# 4       6KgGE8B1RsR7jc9R5nuH0Q    2.5             9
# ...                        ...    ...           ...
# 192604  wWV90q48ugyxyXW6gZav8w    3.5            15
# 192605  phSaT3I_y6To1J2OdeFSUQ    4.0            58
# 192606  oU6Q3ymg1Qsh1EUI6oQwQg    2.5             3
# 192607  gdiOk0n7DmNE9w8xeHWkvw    5.0            15
# 192608  Rv8s4io4G4mcUpiDbpzy7w    5.0             3
#
#                                name  is_open
# 0        Arizona Biltmore Golf Club        0
# 1        Emerald Chinese Restaurant        1
# 2       Nucleus Information Service        1
# 3                      Amazing Cuts        1
# 4                      Ruby Tuesday        0
# ...                             ...      ...
# ...

# %%
dfbusinessAB.rename(columns={'name':'bname', 'is_open':'isOpen'}, inplace=True)
dfbusinessAB.to_csv('businessAB.csv', index=False)

# %%
dfbusinessAB
# Out:
#                    business_id  stars  review_count  \
# 0       1SWheh84yJXfytovILXOAQ    3.0             5
# 1       QXAEGFB4oINsVuTFxEYKFQ    2.5           128
# 2       fcXOEZdXYeZqnQ3lGlOXmg    2.0             5
# 3       f2ZWZPENViL92BrFsIgR6w    4.5           116
# 4       6KgGE8B1RsR7jc9R5nuH0Q    2.5             9
# ...                        ...    ...           ...
# 192604  wWV90q48ugyxyXW6gZav8w    3.5            15
# 192605  phSaT3I_y6To1J2OdeFSUQ    4.0            58
# 192606  oU6Q3ymg1Qsh1EUI6oQwQg    2.5             3
# 192607  gdiOk0n7DmNE9w8xeHWkvw    5.0            15
# 192608  Rv8s4io4G4mcUpiDbpzy7w    5.0             3
#
#                               bname  isOpen
# 0        Arizona Biltmore Golf Club       0
# 1        Emerald Chinese Restaurant       1
# 2       Nucleus Information Service       1
# 3                      Amazing Cuts       1
# 4                      Ruby Tuesday       0
# ...                             ...     ...
# ...
