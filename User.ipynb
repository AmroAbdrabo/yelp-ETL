# %% [markdown]
# ### User information

# %%
import pandas as pd
df = pd.read_csv('/Users/amroa/Downloads/yelpdata/yelp-csv/yelp_academic_dataset_user.csv')
df
# Out:
#         average_stars  compliment_cool  compliment_cute  compliment_funny  \
# 0                4.03                1                0                 1
# 1                3.63                1                0                 1
# 2                3.71                0                0                 0
# 3                4.85                0                0                 0
# 4                4.08               80                0                80
# ...               ...              ...              ...               ...
# 778646           3.00                0                0                 0
# 778647           3.85                0                0                 0
# 778648           4.78                0                0                 0
# 778649           1.00                0                0                 0
# 778650           5.00                1                0                 1
#
#         compliment_hot  compliment_list  compliment_more  compliment_note  \
# ...

# %%
df = pd.DataFrame(df[['name','attributes']], columns = ['business_id', 'attributes'])
import numpy as np
for index, row in df.iterrows():
    if (type(row['streetAddr']) is float):
        print('garbage present with index2 '+ str(index))
        print(str(row))
print('done')
